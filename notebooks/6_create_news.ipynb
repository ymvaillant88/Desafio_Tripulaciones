# %%
import pandas as pd
#import mysql.connector
import datetime

from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

# %% [markdown]
# ## Conexión a la base de datos MongoDB

# %%
uri = "mongodb+srv://goner10:tetete@cluster1.jsr8w0n.mongodb.net/?retryWrites=true&w=majority"
client = MongoClient(uri, server_api=ServerApi('1'))

# %%
# Enviar un ping para confirmar una conexión exitosa
try:
    client.admin.command('ping')
    db = client.get_database("test")
    print("¡Ping a tu implementación exitoso! Te has conectado correctamente a MongoDB.")
except Exception as e:
    print(e)
# Out:
# ¡Ping a tu implementación exitoso! Te has conectado correctamente a MongoDB.

# %%
# Crear una colección de newa en la base de datos test 
newsCollection = db["news"]

# %% [markdown]
# ## Lista de noticias

# %%
# Lista de noticias de página de EDEM
news = [
    {
        'title': 'Elon Musk, el nuevo dueño de la plaza pública digital',
        'body': 'Elon Musk ha puesto sus ojos en Twitter. El tiempo dirá si conseguirá cerrar la compra y si saldrá indemne del debate sobre la libertad de expresión.',
        'date': datetime.datetime.utcnow().isoformat(),
        'imageUrl': 'https://edem.eu/elon-musk-el-nuevo-dueno-de-la-plaza-publica-digital/',
        'tags': '64879e9a5340903bb1ebb0e9',
        'oficial': True
    },
    {
        'title': 'Cinco equipos multidisciplinares de alumnos de EDEM participan en el Vodafone Campus Lab',
        'body': 'Cinco equipos interdisciplinares formados por alumnos de EDEM procedentes de sus grados y másteres resolverán retos en innovación en los que tendrán que contemplar la utilización de Realidad Extendida a través de 5G dentro de la iniciativa Vodafone Campus Lab.',
        'date': datetime.datetime.utcnow().isoformat(),
        'imageUrl': 'https://edem.eu/cinco-equipos-multidisciplinares-de-alumnos-de-edem-participan-en-el-vodafone-campus-lab/',
        'tags': '6489a5a35340903bb1ebb11c',
        'oficial': True
    },
    {
        'title': 'Impacto de la crisis del Covid-19 en los sectores económicos',
        'body': 'Confinamiento, cierre temporal de empresas y restricciones a la movilidad. La crisis causada por el Covid-19 ha golpeado a toda la economía, pero el grado de afectación difiere según el sector económico analizado.',
        'date': datetime.datetime.utcnow().isoformat(),
        'imageUrl': 'https://edem.eu/impacto-de-la-crisis-del-covid-19-en-los-sectores-economicos/',
        'tags': '64879e9a5340903bb1ebb0d2',
        'oficial': True
    },
    {
        'title': 'Juan Roig pone en valor la figura del empresario y del emprendedor en la Universitat de València',
        'body': 'El presidente de Honor de EDEM ha defendido la figura del empresario y el emprendedor: “Estoy orgulloso de ser empresario. Tenemos que estar orgullosos de nuestras empresas y de los emprendedores que se lanzan a la piscina”.',
        'date': datetime.datetime.utcnow().isoformat(),
        'imageUrl': 'https://edem.eu/juan-roig-pone-en-valor-la-figura-del-empresario-y-del-emprendedor-en-la-universitat-de-valencia/',
        'tags': '6489af585340903bb1ebb11e',
        'oficial': True
    },
    {
        'title': 'Juan Roig, primer español que entra en la Academia de Emprendedores Distinguidos de Babson College',
        'body': 'Juan Roig, presidente de Mercadona y presidente de honor de EDEM Escuela de Empresarios, ha sido honrado por Babson College incorporándole a la Academy of Distinguished Entrepreneurs (Academia de Emprendedores Distinguidos), el principal ‘hall of fame’ del emprendimiento del mundo.',
        'date': datetime.datetime.utcnow().isoformat(),
        'imageUrl': 'https://edem.eu/juan-roig-primer-espanol-academia-emprendedores-distinguidos-babson/',
        'tags': '6489af585340903bb1ebb11e',
        'oficial': True
    },
    {
        'title': 'Juan Roig apadrina la primera promoción del Grado en ADE para Emprendedores de EDEM',
        'body': 'El Salón de Actos de EDEM Escuela de Empresarios ha acogido esta tarde la graduación de la primera promoción del Grado en ADE para Emprendedores. Los alumnos han estado apadrinados por Juan Roig, presidente de Mercadona y vicepresidente de EDEM, quien también es profesor del Grado adscrito a la Universitat de València (UV).',
        'date': datetime.datetime.utcnow().isoformat(),
        'imageUrl': 'https://edem.eu/juan-roig-apadrina-la-primera-promocion-del-grado-en-ade-para-emprendedores-de-edem/',
        'tags': '6489a5a35340903bb1ebb11c',
        'oficial': True
    }
]

# %% [markdown]
# ## Inserción de noticias en la base de datos

# %%
newsCollection.insert_many(news)

# %%
# # Mostrar los documentos de la colección
for new in newsCollection.find():
    print(new)
    # Guardar los datos en un dataframe
    df = pd.DataFrame(list(newsCollection.find()))
# Out:
# {'_id': ObjectId('6480c025ca48253bf6963b0f'), 'title': 'title', 'body': 'body', 'date': datetime.datetime(2023, 6, 7, 17, 36, 37, 901000), '__v': 0, 'imageUrl': 'https://www.shutterstock.com/image-vector/breaking-news-template-3d-red-260nw-1906618906.jpg'}
# {'_id': ObjectId('6480cb4e16590b81c2b23548'), 'title': 'Soy Marcelo', 'body': 'Porque me llamo Marcelo', 'date': datetime.datetime(2023, 6, 7, 18, 24, 14, 396000), '__v': 0, 'imageUrl': 'https://www.shutterstock.com/image-vector/breaking-news-template-3d-red-260nw-1906618906.jpg'}
# {'_id': ObjectId('6485ebe3a37ddae5af8a5819'), 'title': 'New1', 'body': 'Body2', 'imageUrl': 'https://imagenes.atresplayer.com/atp/clipping/cmsimages02/2021/12/01/0F708B69-97F8-4000-9A91-91BA75AF93B2//480x270.jpg', 'tags': ['tech', 'sports'], 'oficial': True, 'date': datetime.datetime(2023, 6, 11, 15, 44, 35, 260000), '__v': 0}
# ...

# %%
# Guardar las noticias en un archivo csv
df
# Out:
#                          _id  \
# 0   6480c025ca48253bf6963b0f
# 1   6480cb4e16590b81c2b23548
# 2   6485ebe3a37ddae5af8a5819
# 3   6485ec10a37ddae5af8a581b
# 4   6485eca9a37ddae5af8a581d
# 5   6485ece9a37ddae5af8a581f
# 6   6485ed01a37ddae5af8a5821
# 7   6489b3bdb4a3fd7493b93780
# 8   6489b3bdb4a3fd7493b9377c
# 9   6489b3bdb4a3fd7493b9377f
# 10  6489b3bdb4a3fd7493b93781
# 11  6489b3bdb4a3fd7493b9377d
# 12  6489b3bdb4a3fd7493b9377e
# 13  6489c8f39825af5df5fdae64
# 14  6489c9b69825af5df5fdae66
# 15  6489ca5c9825af5df5fdae69
# 16  6489caf99825af5df5fdae6b
# 17  6489cc719825af5df5fdae6d
# 18  6489e399b6962cc905857163
# 19  648a3e7807c10de0a622f71b
# 20  648a3e9407c10de0a622f71d
# 21  648a3ebc07c10de0a622f71f
# 22  648a3ecf07c10de0a622f721
# 23  648a3ee007c10de0a622f723
# 24  648a3f0807c10de0a622f725
# 25  648a3f4907c10de0a622f727
# 26  648a3f6a07c10de0a622f729
# 27  648a3f8007c10de0a622f72b
#
#                                                 title  \
# ...

# %%
# Obtener las filas de las noticias donde imageUrl sea vacío
df[df["imageUrl"].isnull()]
# Out:
# Empty DataFrame
# Columns: [_id, title, body, date, __v, imageUrl, tags, oficial, createdBy]
# Index: []

# %%
# Obtener las urls de las imágenes unicas de los eventos
df["imageUrl"].unique()
# Out:
# array(['https://www.shutterstock.com/image-vector/breaking-news-template-3d-red-260nw-1906618906.jpg',
#        'https://imagenes.atresplayer.com/atp/clipping/cmsimages02/2021/12/01/0F708B69-97F8-4000-9A91-91BA75AF93B2//480x270.jpg',
#        'https://www.shutterstock.com/image-vector/emotional-intelligence-leadership-concept-260nw-1894855120.jpg'],
#       dtype=object)

# %%
# Poner imagen por defecto a las noticias que no tienen imagen
newsCollection.update_many(
    {"imageUrl": None},
    {"$set": {"imageUrl": "https://www.shutterstock.com/image-vector/breaking-news-template-3d-red-260nw-1906618906.jpg"}}
)

# %%
# Actualizar las urls de las imágenes de las noticias
newsCollection.update_many(
    {"imageUrl": "https://edem.eu/juan-roig-pone-en-valor-la-figura-del-empresario-y-del-emprendedor-en-la-universitat-de-valencia/"},
    {"$set": {"imageUrl": "https://imagenes.atresplayer.com/atp/clipping/cmsimages02/2021/12/01/0F708B69-97F8-4000-9A91-91BA75AF93B2//480x270.jpg"}}
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   _id        28 non-null     object
#  1   title      28 non-null     object
#  2   body       28 non-null     object
#  3   date       28 non-null     object
#  4   __v        22 non-null     float64
#  5   imageUrl   28 non-null     object
#  6   tags       26 non-null     object
#  7   oficial    26 non-null     object
#  8   createdBy  9 non-null      object
# dtypes: float64(1), object(8)
# memory usage: 2.1+ KB

# %%
# Dejar solo las filas desde las 7 hasta las 12
e = df.iloc[7:13]
e
# Out:
#                          _id  \
# 7   6489b3bdb4a3fd7493b9377c
# 8   6489b3bdb4a3fd7493b9377d
# 9   6489b3bdb4a3fd7493b9377e
# 10  6489b3bdb4a3fd7493b9377f
# 11  6489b3bdb4a3fd7493b93780
# 12  6489b3bdb4a3fd7493b93781
#
#                                                 title  \
# 7   Elon Musk, el nuevo dueño de la plaza pública ...
# 8   Cinco equipos multidisciplinares de alumnos de...
# 9   Impacto de la crisis del Covid-19 en los secto...
# 10  Juan Roig pone en valor la figura del empresar...
# 11  Juan Roig, primer español que entra en la Acad...
# 12  Juan Roig apadrina la primera promoción del Gr...
#
#                                                  body  \
# 7   Elon Musk ha puesto sus ojos en Twitter. El ti...
# 8   Cinco equipos interdisciplinares formados por ...
# 9   Confinamiento, cierre temporal de empresas y r...
# 10  El presidente de Honor de EDEM ha defendido la...
# 11  Juan Roig, presidente de Mercadona y president...
# ...

# %%
# Guardar el dataframe en un archivo csv
e.to_csv('File/news.csv', index=False)
